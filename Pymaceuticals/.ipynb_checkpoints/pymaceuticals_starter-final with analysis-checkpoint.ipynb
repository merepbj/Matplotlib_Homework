# %% [markdown]
# ## Observations and Insights

# %%
#Capomulin is a front runner along with Ramicane as the two drug regimens share similar results with reducing tumor volume.
#This is evidenced in their similar means, medians, variances, std dev and SEM for the tumor volume as a result of the drug
#regimen.  Meanwhile, Infubinol, and Ceftamin do not share similar results in reducing tumor volume.

#While Capomulin has a slightly higher median tumor volume relative to Ramicane, it has less variability as
#visualized in the boxplot. 

#Finally, the higher subject weight lessens the effectiveness of Capomulin in reducing the tumor volume.  This is proven by
#a r2 value of .71.  This indicates that 71% of the data can be explained by the mouse's weight.
#The scatter plot below details the mouse's weight and resulting tumor volume from Capomulin drug regimen.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from sklearn import datasets

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combine_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
# Display the data table for preview
combine_df.head(300)
# Out:
#     Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane  Male          21          16          0
# 1       k403     Ramicane  Male          21          16          5
# 2       k403     Ramicane  Male          21          16         10
# 3       k403     Ramicane  Male          21          16         15
# 4       k403     Ramicane  Male          21          16         20
# ..       ...          ...   ...         ...         ...        ...
# 295     b742    Capomulin  Male           7          21         25
# 296     b742    Capomulin  Male           7          21         30
# 297     b742    Capomulin  Male           7          21         35
# 298     b742    Capomulin  Male           7          21         40
# 299     b742    Capomulin  Male           7          21         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             45.000000                 0
# 1             38.825898                 0
# ...

# %%
# Checking the number of mice.
total_mice = len(pd.unique(combine_df["Mouse ID"]))
total_mice_df = pd.DataFrame({"Number of Mice":[total_mice]})
total_mice_df
# Out:
#    Number of Mice
# 0             249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
# Finding all data for a particular Mouse ID and show the duplicate Mouse ID
combine_df[["Mouse ID","Timepoint"]]
duplicate_rows = combine_df[combine_df.duplicated()]
duplicate_rows.head()
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909                45.0                 0

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_rows = combine_df[combine_df["Mouse ID"]=="g989"]
duplicate_rows
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
dupmouseid_index = combine_df[combine_df["Mouse ID"]=="g989"].index
combine_df.drop(dupmouseid_index, inplace=True)
combine_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
nodupmouseID = len(pd.unique(combine_df["Mouse ID"]))
nodupmouseID = pd.DataFrame({"# of No Duplicate Mouse ID": [nodupmouseID]})
nodupmouseID
# Out:
#    # of No Duplicate Mouse ID
# 0                         248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
tumor_mean = combine_df.groupby("Drug Regimen").mean()["Tumor Volume (mm3)"]
tumor_median = combine_df.groupby("Drug Regimen").median()["Tumor Volume (mm3)"]
tumor_variance = combine_df.groupby("Drug Regimen").var()["Tumor Volume (mm3)"]
tumor_std = combine_df.groupby("Drug Regimen").std()["Tumor Volume (mm3)"]
tumor_SEM = combine_df.groupby("Drug Regimen").sem()["Tumor Volume (mm3)"]

regimen_result = pd.DataFrame({"Mean":tumor_mean, "Median":tumor_median, "Variance":tumor_variance, "Std Dev":tumor_std, "SEM":tumor_SEM})
regimen_result
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
tumor_by_regimen_agg = combine_df.groupby("Drug Regimen").agg({"Tumor Volume (mm3)":["mean", "median", "var", "std", "sem"]})
tumor_by_regimen_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.
total_measurements = combine_df.groupby("Drug Regimen").count()["Mouse ID"]
total_measurements_df = pd.DataFrame({"Total Measures":total_measurements})

total_measurements_df.plot(kind ="bar")
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
total_measurements = combine_df.groupby("Drug Regimen").count()["Mouse ID"]
total_measurements_df = pd.DataFrame({"Total Measures":total_measurements})

plt.bar(total_measurements_df.index.values,total_measurements_df["Total Measures"], align = "center")
plt.xticks(rotation = "vertical")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_dist = combine_df["Sex"].value_counts()

gender_dist.plot(kind = "pie",autopct="%1.1f%%")
plt.title("Female vs. Male Mice Distribution", fontsize=30)
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ["Female", "Male"]
colors = ["Orange", "Blue"]
sizes = [922,958]
Explode = (0.1, 0)

plt.pie(sizes, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True)
plt.title("Female vs. Male Mice Distribution", y=1.02, fontsize=22);
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = combine_df.groupby("Mouse ID").max()["Timepoint"].reset_index()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_combine_df = pd.merge(last_timepoint, combine_df, on=["Mouse ID", "Timepoint"])
new_combine_df
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for x in treatment_list:
    treatment_drug = new_combine_df.loc[new_combine_df["Drug Regimen"]==x]["Tumor Volume (mm3)"]
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol_data.append(treatment_drug)
    quartiles = treatment_drug.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq

    print(f"For {x}, the lower quartile of tumor volume data is: {lowerq}")
    print(f"For {x}, the upper quartile of tumor volume data is: {upperq}")
    print(f"For {x}, the interquartile range of tumor volume data is: {iqr}")
    print(f"For {x}, the the median of tumor volume data is: {quartiles[0.5]} ")
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    outlier = treatment_drug.loc[(treatment_drug<lower_bound)|(treatment_drug>upper_bound)]

    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    print("Drug Regimen "+ x + " could have a potential outlier of " + str(outlier))
# Out:
# For Capomulin, the lower quartile of tumor volume data is: 32.37735684
# For Capomulin, the upper quartile of tumor volume data is: 40.1592203
# For Capomulin, the interquartile range of tumor volume data is: 7.781863460000004
# For Capomulin, the the median of tumor volume data is: 38.125164399999996
# Values below 20.70456164999999 could be outliers.
# Values above 51.83201549 could be outliers.
# Drug Regimen Capomulin could have a potential outlier of Series([], Name: Tumor Volume (mm3), dtype: float64)
# For Ramicane, the lower quartile of tumor volume data is: 31.56046955
# For Ramicane, the upper quartile of tumor volume data is: 40.65900627
# For Ramicane, the interquartile range of tumor volume data is: 9.098536719999998
# For Ramicane, the the median of tumor volume data is: 36.56165229
# Values below 17.912664470000003 could be outliers.
# Values above 54.30681135 could be outliers.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
plt.boxplot(tumor_vol_data)
plt.xlabel("Drug Regimen", labelpad=15)
plt.ylabel("Tumor Volume", labelpad=15)
plt.xticks([1,2,3,4],['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])
plt.title("Box Plots of final Tumor Volume Data for Four of the Drug Regimens", y=1.02, fontsize=22);
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = combine_df.loc[combine_df["Drug Regimen"]== "Capomulin"] 
mouse = capomulin_df.loc[capomulin_df["Mouse ID"] == "b742"]
x = mouse["Timepoint"]
y = mouse["Tumor Volume (mm3)"]
plt.plot(x,y, color="red")
plt.xlabel("Timepoint", labelpad=15)
plt.ylabel("Tumor Volume (mm3)", labelpad=15)
plt.title("Tumor Volume vs. Timepoint for Mouse b742 Treated with Capomulin", y=1.02, fontsize=22);
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_average_tumor_vol = capomulin_df.groupby(["Mouse ID"]).mean()
plt.scatter(capomulin_average_tumor_vol["Weight (g)"], capomulin_average_tumor_vol["Tumor Volume (mm3)"])
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Average Tumor Volume vs. Mouse Weight for the Capomulin Drug Regimen", y=1.02, fontsize=18);

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = capomulin_average_tumor_vol["Weight (g)"]
y_values = capomulin_average_tumor_vol["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,25),fontsize=15,color="red")
plt.title("Correlation of Mouse Weight and Tumor Volume for a Mouse Treated with Capomulin", y=1.02, fontsize=18);
plt.xlabel('Mouse Weight')
plt.ylabel('Tumor Volume')
print(f"The R value (i.e. Coefficient of Correlation) is: {rvalue}")
print(f"The R squared value (i.e. Coefficient of Determination) is: {rvalue**2}")
plt.show()
# Out:
# y = 0.95x + 21.55
# The R value (i.e. Coefficient of Correlation) is: 0.8419363424694718
# The R squared value (i.e. Coefficient of Determination) is: 0.7088568047708717
